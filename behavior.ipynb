# %% [markdown]
# <a href="https://colab.research.google.com/github/SaYaNa1234567/ML/blob/main/behavior.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn. model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('social_media_user_behavior.csv')
df.head()
# Out:
#     user_id  age             gender   country    profession primary_platform  \
# 0  USR00001   30             Female        UK        Doctor         Facebook
# 1  USR00002   25               Male       USA  Entrepreneur        Instagram
# 2  USR00003   32               Male       UAE    Freelancer           TikTok
# 3  USR00004   39  Prefer not to say  Pakistan         Other           TikTok
# 4  USR00005   25               Male        UK         Other          YouTube
#
#    platforms_used_count  daily_usage_hours  sessions_per_day  \
# 0                     1                1.6                 2
# 1                     2                2.4                 5
# 2                     5                0.5                 6
# 3                     4                3.0                 7
# 4                     3                3.9                 7
#
#    avg_session_duration_min preferred_device     peak_usage_time  \
# 0                      48.0       Smartphone  Late Night (12am+)
# ...

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import DBSCAN

# %%
df_original = df.copy()
df_model = df.copy()

encoders = {}
text_columns = []
cols_drop1 = ['user_id']
for col in cols_drop1:
  if col in df_model.columns:
    df_model = df_model.drop(columns=[col])
    if col in df_original.columns:
      df_model = df_original.drop(columns=[col])
for col in df_model.columns:
  if df_model[col].dtype in ['object', 'string']:
    le = LabelEncoder()
    text_columns.append(col)
    df_model[col] = le.fit_transform(df_model[col].astype(str))
    encoders[col] = le

df_model.head()
# Out:
#    age  gender  country  profession  primary_platform  platforms_used_count  \
# 0   30       0        8           1                 0                     1
# 1   25       1        9           3                 1                     2
# 2   32       1        7           4                 5                     5
# 3   39       3        6           6                 5                     4
# 4   25       1        8           6                 7                     3
#
#    daily_usage_hours  sessions_per_day  avg_session_duration_min  \
# 0                1.6                 2                      48.0
# 1                2.4                 5                      28.8
# 2                0.5                 6                       5.0
# 3                3.0                 7                      25.7
# 4                3.9                 7                      33.4
#
#    preferred_device  peak_usage_time  followers_count  following_count  \
# ...

# %%
X = df_model
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
min_samples = max(3, X_scaled.shape[1]*2)
dbscan = DBSCAN(eps = 1.0, min_samples=min_samples)
clusters = dbscan.fit_predict(X_scaled)
df_model['clusters'] = clusters
df_original['clusters'] = clusters
